# %%
import pandas as pd

# %%
df = pd.read_csv('data/minjust2018.csv', header = None, usecols=[4,12,13,14,15,16,17,18,19,27,28,33])
df.rename(columns = 
          {4:"Name", 
           12: 'Oblast',
           13:'District',
           14:'City or Aimak',
           15:'Microdistrict',
           16: 'Street',
           17:'#',
           18:'Room',
           19:'Telephone',
           27:'Director', 
           28:"Activity",
           33:'Founders',
           },
           inplace=True)

# %%
df.fillna('', inplace=True)

# %%
pd.set_option('display.max_columns', 34)

# %%
df
# Out:
#                                                      Name  \
# 0       Коммерческий кооператив "Семеноводческий произ...
# 1                                       ОО "Кайберен эне"
# 2       Общество с ограниченной ответственностью "Дете...
# 3                  Иностранное Казахское ОсОО "Валькирия"
# 4                                          ОсОО "Harour''
# 5       Государственное предприятие "Иссык-кульское ры...
# 6                        ОсОО Редакция газеты " Эл созу "
# 7            РО "Церковь Евангельских христиан-баптистов"
# 8         Общество с ограниченной ответственностью "Вояж"
# 9             РО "Церковь Евангельских Христян-баптистов"
# 10      Общество с ограниченной ответственностью "Мана...
# 11      Совместное кыргызско-казахстанское общество с ...
# 12                 Производственный кооператив "Кожешкен"
# 13               Государственное предприятие "МЭЭНЕТ-УЮТ"
# 14           Южное отделение Национального агенства связи
# ...

# %%
bishkek= df[df['City or Aimak'].str.contains("Бишкек")]

# %%
bishkek[df['Street'].str.contains('Айтматов')]
# Out:
# /Users/mirbek/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#                                                      Name  \
# 1038         Совместно Кыргызско-Казахское ОсОО "Тайфун "
# 3352    Общество с Ограниченной Ответственностью "Бакы...
# 3738    Общество с ограниченной ответственностью "Тенг...
# 6845    Общество с ограниченной ответственностью "Алья...
# 8366    Общество с ограниченной ответственностью  "Ада...
# 8446    Общество с ограниченной ответственностью «Окна...
# 12872              "Trade Invest Asia"(Трейд Инвест Азия)
# 13247                            ООО "БЕРКУТ-ИНТЕРСЕРВИС"
# 14045   Общество с ограниченной ответственностью "Нави...
# 15545   Общество с ограниченной ответственностью  "Кен...
# 15877   Общество с ограниченной  ответственностью "Акв...
# 26053   Общество с ограниченной ответственнсотью "АЗИЯ...
# ...

# %%
df[df['Founders'].str.contains("Мирбек")]
# Out:
#                                                      Name  \
# 143     ООО "ERMEX GROUP" (увед о смене адреса от 30.0...
# 1878       Общество с ограниченной ответственностью "ТРД"
# 2410    Общество с ограниченной ответственностью Фирма...
# 2662    Общество с ограниченной ответственностью "Айыл...
# 3192                                           ОсОО "ТРД"
# 3318                     Политическая партия «Эл бийлиги»
# 3331    Общество с ограниченной ответственностью "Sino...
# 3421    Общество с ограниченной ответственностью "Гео-...
# 3446    Общество с ограниченной ответственностью "ЭМЖБ...
# 3511             Общественный Фонд "Центр Защиты Детства"
# 3559                        Политическая партия "ЖЫЛДЫЗ"
# 3580         Политическая партия "Бириккен элдик кыймылы"
# 3632                      Политическая партия  «Мекенчил»
# 4256    Общественное молодежное объединение "Ынтымак-Т...
# 4378    Общество с ограниченной ответственностью "Охра...
# ...

# %%
Street=bishkek[df['Street'].str.contains('Айтматов')]
# Out:
# /Users/mirbek/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
Street[df['Founders'].str.contains("Мирбек")]
# Out:
# /Users/mirbek/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# Empty DataFrame
# Columns: [Name, Oblast, District, City or Aimak, Microdistrict, Street, #, Room, Telephone, Director, Activity, Founders]
# Index: []

# %%
df[df['Founders'].str.contains("Токтогараев Ренат")]
# Out:
#                                                      Name            Oblast  \
# 70198   Общество с ограниченной ответственностью "Ойал...           БИШКЕК
# 93016   Общество с ограниченной ответственностью "Сары...           БИШКЕК
# 93079   Общество с ограниченной ответственностью "Буру...           БИШКЕК
# 104801  Общество с ограниченной ответственностью "СУУТАШ"  ЧУЙСКАЯ ОБЛАСТЬ
#
#                    District       City or Aimak Microdistrict  \
# 70198    ПЕРВОМАЙСКИЙ РАЙОН  ПЕРВОМАЙСКИЙ РАЙОН
# 93016    ПЕРВОМАЙСКИЙ РАЙОН  ПЕРВОМАЙСКИЙ РАЙОН
# 93079    ПЕРВОМАЙСКИЙ РАЙОН  ПЕРВОМАЙСКИЙ РАЙОН
# 104801  АЛАМУДУНСКИЙ РАЙОН          КАРА-ДЖЫГАЧ
#
#                  Street    #     Room   Telephone  \
# 70198       ул. Исанова   33  кв. 126
# 93016        ул.Исанова   33   кв.126  0553700883
# 93079       ул. Исанова   33  кв. 126  0553700883
# 104801  ул. Кондучалова  213           0312893484
#
#                                Director  \
# 70198   Токтогараев Ренат Джусупбекович
# ...

# %%
building=df[df['Activity'].str.contains("Строительство")]

# %%
building[df['Telephone'].str.contains("432")]
# Out:
# /Users/mirbek/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#                                                      Name  \
# 20582   Общество с ограниченной ответственностью "Нект...
# 56450   Общество с ограниченной ответственностью "Пром...
# 59419   Общество с ограниченной ответственностью "Теги...
# 63409   Общество с ограниченной ответственностью "Байзат"
# 69270   Общество с ограниченной ответственностью "Альф...
# 71212   Общество с ограниченной ответственностью "ВРЕМ...
# 76404   Филиал Общества с ограниченной ответственность...
# 80891    Общество с ограниченной ответственностью "ЖАКИН"
# 86107   Общество с ограниченной ответственностью "Мара...
# 89052   Общество с ограниченной ответственностью "БАЙН...
# 95065   Общество с ограниченной ответственностью "Паде...
# 96224   Общество с ограниченной ответственностью Строи...
# ...
